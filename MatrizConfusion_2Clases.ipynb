# %%
import pandas as pd

# %%
MatrizConfusion_0 = pd.read_csv("MatricesConfusion_2/MatrizConfusion0.csv")
MatrizConfusion_0
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_1 = pd.read_csv("MatricesConfusion_2/MatrizConfusion1.csv")
MatrizConfusion_1
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_4= pd.read_csv("MatricesConfusion_2/MatrizConfusion4.csv")
MatrizConfusion_4
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_5 = pd.read_csv("MatricesConfusion_2/MatrizConfusion5.csv")
MatrizConfusion_5
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_6 = pd.read_csv("MatricesConfusion_2/MatrizConfusion6.csv")
MatrizConfusion_6
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_7 = pd.read_csv("MatricesConfusion_2/MatrizConfusion7.csv")
MatrizConfusion_7
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_8 = pd.read_csv("MatricesConfusion_2/MatrizConfusion8.csv")
MatrizConfusion_8
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27

# %%
MatrizConfusion_9 = pd.read_csv("MatricesConfusion_2/MatrizConfusion9.csv")
MatrizConfusion_9
# Out:
#   Unnamed: 0  Predijo Si  Predijo No
# 0         Si           3           0
# 1         No           0          27
