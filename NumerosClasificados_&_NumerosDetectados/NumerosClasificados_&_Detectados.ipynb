# %%
import pandas as pd

# %%
NumerosClasificados_Detectados = pd.read_csv("DataFrameNumerosClasificados_&_NumerosDetectados.csv")

# %%
NumerosClasificados_Detectados
# Out:
#     Unnamed: 0  NumerosOriginales  \
# 0            1                  0
# 1            2                  0
# 2            3                  0
# 3            4                  1
# 4            5                  1
# 5            6                  1
# 6            7                  2
# 7            8                  2
# 8            9                  2
# 9           10                  3
# 10          11                  3
# 11          12                  3
# 12          13                  4
# 13          14                  4
# 14          15                  4
# 15          16                  5
# 16          17                  5
# 17          18                  5
# 18          19                  6
# 19          20                  6
# 20          21                  6
# 21          22                  7
# 22          23                  7
# 23          24                  7
# 24          25                  8
# 25          26                  8
# ...
