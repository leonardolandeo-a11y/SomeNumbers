# %%
import pandas as pd

# %%
NumerosClasificados = pd.read_csv("NumerosClasificados.csv")

# %%
NumerosClasificados
# Out:
#     Unnamed: 0  NumerosOriginales  \
# 0            1                  1
# 1            2                  1
# 2            3                  1
# 3            4                  2
# 4            5                  2
# 5            6                  2
# 6            7                  3
# 7            8                  3
# 8            9                  3
# 9           10                  4
# 10          11                  4
# 11          12                  4
# 12          13                  5
# 13          14                  5
# 14          15                  5
# 15          16                  6
# 16          17                  6
# 17          18                  6
# 18          19                  7
# 19          20                  7
# 20          21                  7
# 21          22                  8
# 22          23                  8
# 23          24                  8
# 24          25                  9
# 25          26                  9
# ...
