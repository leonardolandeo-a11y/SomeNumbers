# %%
import pandas as pd

# %%
NumerosClasificados = pd.read_csv("NumerosClasificados.csv")

# %%
NumerosClasificados
# Out:
#     #Imagen  NumerosOriginales                 Vecino 1  \
# 0         1                  1   [1, 34.95542963183069]
# 1         2                  1  [2, 37.035545754931555]
# 2         3                  1   [1, 36.26086887132388]
# 3         4                  2   [2, 36.48385590419181]
# 4         5                  2   [2, 34.73402647485185]
# 5         6                  2   [0, 39.13713348246323]
# 6         7                  3   [9, 33.55685472506074]
# 7         8                  3  [9, 35.032281482469486]
# 8         9                  3  [9, 35.278968426325655]
# 9        10                  4   [8, 33.71821649788937]
# 10       11                  4   [0, 35.48914547247907]
# 11       12                  4   [0, 35.62251468495473]
# 12       13                  5  [8, 35.094888017153764]
# 13       14                  5   [5, 33.26252039999744]
# 14       15                  5   [0, 35.11289618732771]
# 15       16                  6  [0, 36.187866635891304]
# ...
